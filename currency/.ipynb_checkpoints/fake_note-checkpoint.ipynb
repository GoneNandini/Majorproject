# %% [markdown]
# fake note detection

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import seaborn as sns
from sklearn.metrics import f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
import pickle

# %%
def process_jpg_image(img):
  img = tf.convert_to_tensor(img[:,:,:3])
  img = np.expand_dims(img, axis = 0)
  img = tf.image.resize(img,[224,224])
  img = (img/255.0)
  return img

def show_confusion_matrix(cm, labels):
    '''
    plots heatmap of confusion matrix'''
    plt.figure(figsize=(15, 10))
    sns.heatmap(cm, xticklabels=labels, yticklabels=labels, 
              annot=True, fmt='g')
    plt.xlabel('Prediction')
    plt.ylabel('Label')
    plt.show()

# %%
# Load all the images. training folder is split 20% as validation set and testing folder is loaded as test dataset.

train_dir = r"/Users/ala.dharmateja/Desktop/c_1/currency"
preprocess_input = tf.keras.applications.vgg16.preprocess_input
TARGET_SIZE = 224
BATCH_SIZE = 64


train_datagen = ImageDataGenerator(validation_split=0.2,
                                   rescale=1./255)


train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=BATCH_SIZE,
                                                    class_mode='categorical',
                                                    subset="training",
                                                    shuffle = True,
                                                    target_size=(TARGET_SIZE,TARGET_SIZE))

validation_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=BATCH_SIZE,
                                                    class_mode='categorical',
                                                    subset="validation", 
                                                    shuffle = False,
                                                    target_size=(TARGET_SIZE,TARGET_SIZE))
# Out:
# Found 500 images belonging to 2 classes.
# Found 125 images belonging to 2 classes.

# %%
# Print all the classes

train_generator.class_indices
# Out:
# {'fake': 0, 'real': 1}

# %%
for image_batch, labels_batch in train_generator:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64, 2)

# %%
from tensorflow.keras.applications.vgg16 import VGG16


base_model = VGG16(weights='imagenet', input_shape=(TARGET_SIZE, TARGET_SIZE, 3), include_top=False)
base_model.trainable = False

# Adding a model on top

inputs = tf.keras.Input(shape=(TARGET_SIZE, TARGET_SIZE, 3))

x = base_model.output
x = tf.keras.layers.Dropout(0.25)(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.25)(x)
x = tf.keras.layers.Dense(16, activation='relu')(x)
x = tf.keras.layers.Dropout(0.25)(x)
output = tf.keras.layers.Dense(2, activation='softmax')(x)

vgg = tf.keras.Model(inputs=base_model.input, outputs=output)

# %%
vgg.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │         8,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,722,930 (56.16 MB)
#  Trainable params: 8,242 (32.20 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
opt = tf.keras.optimizers.Adam()
cce = tf.keras.losses.BinaryCrossentropy()
vgg.compile(optimizer=opt, loss=cce, metrics= ['acc'])

# %%
checkpoint_filepath = '/Users/ala.dharmateja/Desktop/c_1/best_model.weights.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.001)

# %%
EPOCHS = 50
NUM_STEPS = int(train_generator.samples / BATCH_SIZE)  # Convert to int
VAL_NUM_STEPS = int(validation_generator.samples / BATCH_SIZE)  # Convert to int

model = vgg.fit(
    train_generator, 
    epochs=EPOCHS, 
    steps_per_epoch=NUM_STEPS, 
    validation_steps=VAL_NUM_STEPS, 
    validation_data=validation_generator, 
    callbacks=[reduce_lr]
)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 49s 7s/step - acc: 0.8203 - loss: 0.4584 - val_acc: 0.9219 - val_loss: 0.3855 - learning_rate: 0.0010
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - acc: 0.9062 - loss: 0.3801 - val_acc: 0.9219 - val_loss: 0.3839 - learning_rate: 0.0010
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 49s 7s/step - acc: 0.8418 - loss: 0.4211 - val_acc: 0.8594 - val_loss: 0.4118 - learning_rate: 0.0010
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - acc: 0.8750 - loss: 0.4520 - val_acc: 0.8594 - val_loss: 0.4090 - learning_rate: 0.0010
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 50s 7s/step - acc: 0.8443 - loss: 0.4110 - val_acc: 0.9219 - val_loss: 0.3515 - learning_rate: 0.0010
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - acc: 0.8281 - loss: 0.3520 - val_acc: 0.9219 - val_loss: 0.3456 - learning_rate: 0.0010
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 50s 7s/step
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - acc: 0.9688 - loss: 0.1504 - val_acc: 0.9062 - val_loss: 0.2059 - learning_rate: 0.0010
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 59s 8s/step - acc: 0.9026 - loss: 0.2338 - val_acc: 0.9062 - val_loss: 0.2001 - learning_rate: 0.0010
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - acc: 0.9219 - loss: 0.1960 - val_acc: 0.9062 - val_loss: 0.2040 - learning_rate: 0.0010
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 62s 9s/step - acc: 0.9389 - loss: 0.1905 - val_acc: 0.9062 - val_loss: 0.2259 - learning_rate: 0.0010
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - acc: 0.9531 - loss: 0.1639 - val_acc: 0.9062 - val_loss: 0.2208 - learning_rate: 0.0010
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 60s 8s/step - acc: 0.9390 - loss: 0.1856 - val_acc: 0.9062 - val_loss: 0.1990 - learning_rate: 0.0010
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - acc: 0.9375 - loss: 0.1717 - val_acc: 0.9062 - val_loss: 0.1972 - learning_rate: 0.0010
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 61s 9s/step - acc: 0.9295 - loss: 0.1809 - val_acc: 0.9062 - val_loss: 0.2038 - learning_rate: 0.0010
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - acc: 0.9219 - loss: 0.1997 - val_acc: 0.9062 - val_loss: 0.2015 - learning_rate: 0.0010
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 60s 8s/step - acc: 0.9146 - loss: 0.2242 - val_acc: 0.9062 - val_loss: 0.2086 - learning_rate: 0.0010
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - acc: 0.9531 - loss: 0.1953 - val_acc: 0.9062 - val_loss: 0.2110 - learning_rate: 0.0010
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 58s 8s/step - acc: 0.9422 - loss: 0.1962 - val_acc: 0.9062 - val_loss: 0.2143 - learning_rate: 0.0010
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - acc: 0.9844 - loss: 0.1436 - val_acc: 0.9062 - val_loss: 0.2116 - learning_rate: 0.0010
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 59s 8s/step - acc: 0.9236 - loss: 0.2086 - val_acc: 0.9062 - val_loss: 0.1831 - learning_rate: 0.0010
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - acc: 0.9423 - loss: 0.1437 - val_acc: 0.9062 - val_loss: 0.1886 - learning_rate: 0.0010

# %%
# Save the model to disk

#vgg.save("vgg_model_2.h5")
pickle.dump(vgg, open('vgg-model2.pkl','wb'))

# %%
pick_insert = open('vgg.pickle','wb')
pickle.dump(vgg, pick_insert)
pick_insert.close()

# %%
acc = model.history['acc']
val_acc = model.history['val_acc']

loss = model.history['loss']
val_loss = model.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
class_names = list(train_generator.class_indices.items())
print(class_names)
# Out:
# [('fake', 0), ('real', 1)]

# %%
test_image_path = "/Users/ala.dharmateja/Desktop/c_1/currency/fake/₹7 Crore Fake Currency Notes Seized_ 7....jpg"

# %%
test_image_read_1 = cv2.imread(test_image_path)
test_image_1 = process_jpg_image(test_image_read_1)
prediction_1 = vgg.predict(test_image_1)
print(f'dimensions of image used for prediction is: ',test_image_1.shape)

prediction = int(np.argmax(prediction_1))
print(f"prediction is: ", class_names[prediction][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# dimensions of image used for prediction is:  (1, 224, 224, 3)
# prediction is:  fake

# %%
# Get the labels of all the images
true_labels = validation_generator.labels
# Making the predictions of all the validation images
all_predictions = vgg.predict(validation_generator)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step

# %%
preds = []
for items in all_predictions:
    preds.append(np.argmax(items))

# %%
# plot the confusion matrix

confusion_mat = tf.math.confusion_matrix(
    true_labels, preds, dtype=tf.dtypes.int32)

show_confusion_matrix(confusion_mat, class_names)

# %%
f1 = f1_score(true_labels, preds, average='weighted')
print(f"F1 score of the model is", f1)
# Out:
# F1 score of the model is 0.9516016859852475

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(true_labels, preds)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 95.20%
